# %%
#Récupération des données globales

from bs4 import BeautifulSoup

# Charger le fichier HTML localement
with open('Emploi_Indeed.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analyser le HTML avec BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Extraire le texte de la page
text = soup.get_text()

# Afficher le texte extrait
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Offres Emploi Alternance | Meteojob.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aller au contenu principal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Recruteurs
#
# Déjà client
#
# Recruter sur Meteojob.com
#
#
# Se connecter
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alternance / Apprentissage CDICDDIntérimStageAlternance / ApprentissageIndépendant / FranchiséSaisonnierIntermittentCDICTitulaire de la fonction publiqueVIE - VTEMilitaireContrat d'Engagement EducatifExtraBénévolatCDI IntérimaireCDICDDIntérimStageAlternance / ApprentissageIndépendant / FranchiséSaisonnierIntermittentCDICTitulaire de la fonction publiqueVIE - VTEMilitaireContrat d'Engagement EducatifExtraBénévolatCDI Intérimaire
#
#
#
#
#
#
#
#  Rechercher
#
#
#
#
#
#
#
#
#
#
#
#
# Emploi Alternance
#
#
#
#
#
#
# ...

# %% [markdown]
# # Récupération des annonces

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Charger le fichier HTML localement
with open('Emploi_Indeed.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analyser le HTML avec BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Exemple d'extraction des titres des balises <h1> et <h2>
titles = []
for tag in soup.find_all(['h1', 'h2']):
    titles.append(tag.text)

# Créer un DataFrame pandas avec les données extraites
df = pd.DataFrame({'Titres': titles})

# Afficher le DataFrame
display(df)
# Out:
#                                                Titres
# 0                                              Indeed
# 1   Alternance Assistant ADV et communication - Vi...
# 2   Assistant Evènementiel Examens F/H) - alternan...
# 3   Alternance - Data analyst (F/H) - Saint-Etienn...
# 4   Assistant Organisation Examens (F/H) - alterna...
# 5            Consultant Data Junior H/F en Alternance
# 6   Chargé des admissions (F/H) - alternance - Lyo...
# 7     Assistant de vie aux familles H/F en alternance
# 8               Assistant comptable en alternance H/F
# 9                     Consultant Junior BI - Lyon H/F
# 10                         Stage - Data Science (H/F)
# 11  Chargé de missions projets transverses (H/F) -...
# 12  Consultant Senior Transformation - Secteur Pub...
# 13  (H/F) Alternance - Chargé(e) de communication ...
# 14                         Stage - Data Scientist H/F
# 15                                   Data Analyst F/H
# ...

# %% [markdown]
# # Récupération des société et de la localisation

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Charger le fichier HTML localement
with open('Emploi_Indeed.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analyser le HTML avec BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Exemple d'extraction des titres des balises <h1> et <h2>
titles = []
locations = []
companies = []

for tag in soup.find_all(['h2']):
    titles.append(tag.text)

for tag in soup.find_all('div', class_='css-1p0sjhy eu4oa1w0'):
    location_text = tag.text if tag.text else 'N/A'
    locations.append(location_text)

for tag in soup.find_all('span', class_='css-92r8pb eu4oa1w0'):
    company_text = tag.text if tag.text else 'N/A'
    companies.append(company_text)

# Assurer que toutes les listes ont la même longueur
min_length = min(len(titles), len(locations), len(companies))
titles = titles[:min_length]
locations = locations[:min_length]
companies = companies[:min_length]

# Créer un DataFrame pandas avec les données extraites
df = pd.DataFrame({'Titres': titles, 'Localisation': locations, 'Société': companies})

# Afficher le DataFrame
display(df)
# Out:
#                                                Titres  \
# 0   Alternance Assistant ADV et communication - Vi...
# 1   Assistant Evènementiel Examens F/H) - alternan...
# 2   Alternance - Data analyst (F/H) - Saint-Etienn...
# 3   Assistant Organisation Examens (F/H) - alterna...
# 4            Consultant Data Junior H/F en Alternance
# 5   Chargé des admissions (F/H) - alternance - Lyo...
# 6     Assistant de vie aux familles H/F en alternance
# 7               Assistant comptable en alternance H/F
# 8                     Consultant Junior BI - Lyon H/F
# 9                          Stage - Data Science (H/F)
# 10  Chargé de missions projets transverses (H/F) -...
# 11  Consultant Senior Transformation - Secteur Pub...
# 12  (H/F) Alternance - Chargé(e) de communication ...
# 13                         Stage - Data Scientist H/F
# 14                                   Data Analyst F/H
# 15                      Assistant Data analyst BI H-F
# ...

# %% [markdown]
# # Récupération du salaire et du type d'emploi

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Charger le fichier HTML localement
with open('Emploi_Indeed.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analyser le HTML avec BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Exemple d'extraction des titres des balises <h1> et <h2>
titles = []
locations = []
companies = []
salaries = []
job_types = []

for tag in soup.find_all(['h2']):
    titles.append(tag.text)

for tag in soup.find_all('div', class_='css-1p0sjhy eu4oa1w0'):
    location_text = tag.text if tag.text else 'N/A'
    locations.append(location_text)

for tag in soup.find_all('span', class_='css-92r8pb eu4oa1w0'):
    company_text = tag.text if tag.text else 'N/A'
    companies.append(company_text)

for tag in soup.find_all('div', class_='metadata salary-snippet-container css-5zy3wz eu4oa1w0'):
    salary_text = tag.text if tag.text else 'N/A'
    salaries.append(salary_text)

for tag in soup.find_all('div', class_='metadata css-5zy3wz eu4oa1w0'):
    job_type_text = tag.text if tag.text else 'N/A'
    job_types.append(job_type_text)

# Assurer que toutes les listes ont la même longueur
min_length = min(len(titles), len(locations), len(companies), len(salaries), len(job_types))
titles = titles[:min_length]
locations = locations[:min_length]
companies = companies[:min_length]
salaries = salaries[:min_length]
job_types = job_types[:min_length]

# Créer un DataFrame pandas avec les données extraites
df = pd.DataFrame({'Titres': titles, 'Localisation': locations, 'Société': companies, 'Salaire': salaries, 'Type d\'emploi': job_types})

# Afficher le DataFrame
display(df)
# Out:
#                                                Titres  \
# 0   Alternance Assistant ADV et communication - Vi...
# 1   Assistant Evènementiel Examens F/H) - alternan...
# 2   Alternance - Data analyst (F/H) - Saint-Etienn...
# 3   Assistant Organisation Examens (F/H) - alterna...
# 4            Consultant Data Junior H/F en Alternance
# 5   Chargé des admissions (F/H) - alternance - Lyo...
# 6     Assistant de vie aux familles H/F en alternance
# 7               Assistant comptable en alternance H/F
# 8                     Consultant Junior BI - Lyon H/F
# 9                          Stage - Data Science (H/F)
# 10  Chargé de missions projets transverses (H/F) -...
# 11  Consultant Senior Transformation - Secteur Pub...
# 12  (H/F) Alternance - Chargé(e) de communication ...
# 13                         Stage - Data Scientist H/F
# 14                                   Data Analyst F/H
#
#                Localisation                               Société  \
# ...

# %% [markdown]
# # Récupération du lien de l'annonce

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Charger le fichier HTML localement
with open('Emploi_Indeed.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# Analyser le HTML avec BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Exemple d'extraction des titres des balises <h1> et <h2>
titles = []
locations = []
companies = []
salaries = []
job_types = []
links = []

for tag in soup.find_all(['h2']):
    titles.append(tag.text)

for tag in soup.find_all('div', class_='css-1p0sjhy eu4oa1w0'):
    location_text = tag.text if tag.text else 'N/A'
    locations.append(location_text)

for tag in soup.find_all('span', class_='css-92r8pb eu4oa1w0'):
    company_text = tag.text if tag.text else 'N/A'
    companies.append(company_text)

for tag in soup.find_all('div', class_='metadata salary-snippet-container css-5zy3wz eu4oa1w0'):
    salary_text = tag.text if tag.text else 'N/A'
    salaries.append(salary_text)

for tag in soup.find_all('div', class_='metadata css-5zy3wz eu4oa1w0'):
    job_type_text = tag.text if tag.text else 'N/A'
    job_types.append(job_type_text)

for tag in soup.find_all('a', class_='jcs-JobTitle css-jspxzf eu4oa1w0', href=True):
    link = tag['href']
    links.append(link)

# Assurer que toutes les listes ont la même longueur
min_length = min(len(titles), len(locations), len(companies), len(salaries), len(job_types), len(links))
titles = titles[:min_length]
locations = locations[:min_length]
companies = companies[:min_length]
salaries = salaries[:min_length]
job_types = job_types[:min_length]
links = links[:min_length]

# Créer un DataFrame pandas avec les données extraites
df = pd.DataFrame({'Titres': titles, 'Localisation': locations, 'Société': companies, 'Salaire': salaries, 'Type d\'emploi': job_types, 'Lien': links})

# Afficher le DataFrame
display(df)
# Out:
#                                                Titres  \
# 0   Alternance Assistant ADV et communication - Vi...
# 1   Assistant Evènementiel Examens F/H) - alternan...
# 2   Alternance - Data analyst (F/H) - Saint-Etienn...
# 3   Assistant Organisation Examens (F/H) - alterna...
# 4            Consultant Data Junior H/F en Alternance
# 5   Chargé des admissions (F/H) - alternance - Lyo...
# 6     Assistant de vie aux familles H/F en alternance
# 7               Assistant comptable en alternance H/F
# 8                     Consultant Junior BI - Lyon H/F
# 9                          Stage - Data Science (H/F)
# 10  Chargé de missions projets transverses (H/F) -...
# 11  Consultant Senior Transformation - Secteur Pub...
# 12  (H/F) Alternance - Chargé(e) de communication ...
# 13                         Stage - Data Scientist H/F
# 14                                   Data Analyst F/H
#
#                Localisation                               Société  \
# ...

# %% [markdown]
# # Factorisation

# %%
import pandas as pd
from bs4 import BeautifulSoup

def extract_data_from_html(file_path):
    # Charger le fichier HTML localement
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()

    # Analyser le HTML avec BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extraire les données
    titles = [tag.text for tag in soup.find_all('h2')]
    locations = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='css-1p0sjhy eu4oa1w0')]
    companies = [tag.text if tag.text else 'N/A' for tag in soup.find_all('span', class_='css-92r8pb eu4oa1w0')]
    salaries = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='metadata salary-snippet-container css-5zy3wz eu4oa1w0')]
    job_types = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='metadata css-5zy3wz eu4oa1w0')]
    links = [tag['href'] for tag in soup.find_all('a', class_='jcs-JobTitle css-jspxzf eu4oa1w0', href=True)]

    # Assurer que toutes les listes ont la même longueur
    min_length = min(len(titles), len(locations), len(companies), len(salaries), len(job_types), len(links))
    titles = titles[:min_length]
    locations = locations[:min_length]
    companies = companies[:min_length]
    salaries = salaries[:min_length]
    job_types = job_types[:min_length]
    links = links[:min_length]

    # Créer un DataFrame pandas avec les données extraites
    df = pd.DataFrame({'Titres': titles, 'Localisation': locations, 'Société': companies, 'Salaire': salaries, 'Type d\'emploi': job_types, 'Lien': links})

    return df

# Utilisation de la fonction pour extraire les données du fichier HTML
df = extract_data_from_html('Emploi_Indeed.html')

# Afficher le DataFrame
display(df)
# Out:
#                                                Titres  \
# 0   Alternance Assistant ADV et communication - Vi...
# 1   Assistant Evènementiel Examens F/H) - alternan...
# 2   Alternance - Data analyst (F/H) - Saint-Etienn...
# 3   Assistant Organisation Examens (F/H) - alterna...
# 4            Consultant Data Junior H/F en Alternance
# 5   Chargé des admissions (F/H) - alternance - Lyo...
# 6     Assistant de vie aux familles H/F en alternance
# 7               Assistant comptable en alternance H/F
# 8                     Consultant Junior BI - Lyon H/F
# 9                          Stage - Data Science (H/F)
# 10  Chargé de missions projets transverses (H/F) -...
# 11  Consultant Senior Transformation - Secteur Pub...
# 12  (H/F) Alternance - Chargé(e) de communication ...
# 13                         Stage - Data Scientist H/F
# 14                                   Data Analyst F/H
#
#                Localisation                               Société  \
# ...

# %% [markdown]
# # Requête en ligne

# %%
import requests

cookies = {
    'CTK': '1hopbo6jii926800',
    'RF': '"TFTzyBUJoNr6YttPP3kyivpZ6-9J49o-Uk3iY6QNQqKE2fh7FyVgtV2jl_SUJp1hd5JYQQTTjTQ="',
    'CSRF': 's7qE3uD7e3ZGd9iUtrl24mcuQMZ6VjqG',
    'INDEED_CSRF_TOKEN': 'BBl9vEGyCVOlELLHMX4pfA8TvpOYdzm0',
    'LV': '"LA=1710248172:CV=1710248172:TS=1710248172"',
    'hpnode': '1',
    '__cf_bm': 'ms.PIK_94iKs_1raEa9_HBtKYE_abnA1BqnkKo.D6jc-1710248172-1.0.1.1-WQ5_0wzwoJGBjD1oS0jpl2lt04uqSvqFUylpJzLaq_5.IItoT1koW2vVJqta.nOx_LZzNAQcoxxuKwYYQdco2A',
    '_cfuvid': 'w0jqBBZeIbKERO4o8H0Yrs4rlNin_G6EiSGiRG.XSYs-1710248172192-0.0.1.1-604800000',
    'indeed_rcc': 'LV',
    'SURF': 'k6Ni2DRtV5zSs9tpJ1k9ZIxSu2l5nbGN',
    'PREF': '"TM=1710248182794:L=Lyon+%2869%29"',
    '_gcl_au': '1.1.1215712898.1710248183',
    'LC': '"co=FR"',
    'OptanonAlertBoxClosed': '2024-03-12T12:56:25.782Z',
    'gonetap': '1',
    'LOCALE': 'fr',
    'MICRO_CONTENT_CSRF_TOKEN': 'FkbFFQzBVqXd126yzawgwpdBHJKWvROH',
    'PPID': '""',
    'RQ': '"q=data&l=Lyon+%2869%29&ts=1710248905539"',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Tue+Mar+12+2024+14%3A08%3A25+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202210.1.0&isIABGlobal=false&hosts=&consentId=210fa247-8980-47b0-8ab0-d3109ae308c9&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0%2CC0007%3A0&AwaitingReconsent=false&geolocation=%3B',
    'JSESSIONID': 'DEBDEEE1F6112D526FAB175D81C441C7',
}

headers = {
    'authority': 'fr.indeed.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'fr-FR,fr;q=0.9',
    'cache-control': 'max-age=0',
    #'cookie': 'CTK=1hopbo6jii926800; RF="TFTzyBUJoNr6YttPP3kyivpZ6-9J49o-Uk3iY6QNQqKE2fh7FyVgtV2jl_SUJp1hd5JYQQTTjTQ="; CSRF=s7qE3uD7e3ZGd9iUtrl24mcuQMZ6VjqG; INDEED_CSRF_TOKEN=BBl9vEGyCVOlELLHMX4pfA8TvpOYdzm0; LV="LA=1710248172:CV=1710248172:TS=1710248172"; hpnode=1; __cf_bm=ms.PIK_94iKs_1raEa9_HBtKYE_abnA1BqnkKo.D6jc-1710248172-1.0.1.1-WQ5_0wzwoJGBjD1oS0jpl2lt04uqSvqFUylpJzLaq_5.IItoT1koW2vVJqta.nOx_LZzNAQcoxxuKwYYQdco2A; _cfuvid=w0jqBBZeIbKERO4o8H0Yrs4rlNin_G6EiSGiRG.XSYs-1710248172192-0.0.1.1-604800000; indeed_rcc=LV; SURF=k6Ni2DRtV5zSs9tpJ1k9ZIxSu2l5nbGN; PREF="TM=1710248182794:L=Lyon+%2869%29"; _gcl_au=1.1.1215712898.1710248183; LC="co=FR"; OptanonAlertBoxClosed=2024-03-12T12:56:25.782Z; gonetap=1; LOCALE=fr; MICRO_CONTENT_CSRF_TOKEN=FkbFFQzBVqXd126yzawgwpdBHJKWvROH; PPID=""; RQ="q=data&l=Lyon+%2869%29&ts=1710248905539"; OptanonConsent=isGpcEnabled=0&datestamp=Tue+Mar+12+2024+14%3A08%3A25+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202210.1.0&isIABGlobal=false&hosts=&consentId=210fa247-8980-47b0-8ab0-d3109ae308c9&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0%2CC0007%3A0&AwaitingReconsent=false&geolocation=%3B; JSESSIONID=DEBDEEE1F6112D526FAB175D81C441C7',
    'referer': 'https://fr.indeed.com/jobs?q=data&l=Lyon+%2869%29&from=searchOnHP',
    'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
}

params = {
    'q': 'data',
    'l': 'Lyon (69)',
    'start': '10',
}

response = requests.get('https://fr.indeed.com/jobs', params=params, cookies=cookies, headers=headers)
response
# Out:
# <Response [403]>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def extract_data_from_indeed(url, headers=None, cookies=None, params=None):
    # Faire une requête GET à l'URL spécifiée
    response = requests.get('https://fr.indeed.com/', params=params, cookies=cookies, headers=headers)

    # Vérifier si la requête a réussi
    if response.status_code == 200:
        # Extraire le contenu HTML
        html_content = response.text
        
        # Analyser le HTML avec BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extrait le texte de toutes les balises <h2>
        titles = [tag.text for tag in soup.find_all('h2', class_='title')]

        # Extrait le texte de toutes les balises <span> avec la classe 'company'
        companies = [tag.text.strip() if tag.text.strip() else 'N/A' for tag in soup.find_all('span', class_='company')]

        # Extrait le texte de toutes les balises <span> avec la classe 'location'
        locations = [tag.text.strip() if tag.text.strip() else 'N/A' for tag in soup.find_all('span', class_='location')]

        # Extrait le texte de toutes les balises <div> avec la classe 'salaryText'
        salaries = [tag.text.strip() if tag.text.strip() else 'N/A' for tag in soup.find_all('div', class_='salaryText')]

        # Créer un DataFrame pandas avec les données extraites
        df = pd.DataFrame({'Titres': titles, 'Société': companies, 'Localisation': locations, 'Salaire': salaries})

        return df
    else:
        print("Erreur lors de la récupération des données. Code de statut:", response.status_code)
        return None

# URL de la page Indeed à consulter
url = 'https://fr.indeed.com/'
import requests

cookies = {
    'CTK': '1hno0tooh2m1c000',
    'RF': '"TFTzyBUJoNr6YttPP3kyivpZ6-9J49o-Uk3iY6QNQqKE2fh7FyVgtUFwLlPtlI5qOkaXVE69j0U="',
    '_gcl_au': '1.1.1119145322.1709129525',
    'OptanonAlertBoxClosed': '2024-02-28T14:12:10.262Z',
    'LC': '"co=FR"',
    'LOCALE': 'fr',
    'hpnode': '1',
    'PREF': '"TM=1709886391943:L=Lyon+%2869%29"',
    'ROJC': '9c170ca4a4a2c6df:d780cf2769d0d6a7',
    'CMP_VISITED': '1',
    'cmppmeta': '"eNoBSAC3/wXQdiyC3wYaLjImdD8rMIyQp2dANXSxRCBjkgkFr4KBh8sXcTR9iRx1JPiXOXUjYqn9N3emZ3QWeGMcA8D5zb3gyaS90ae4B/ZQH14="',
    'CSRF': 'b8hboeTP7lH9ORXlUCzaTyulajHaGEA4',
    'INDEED_CSRF_TOKEN': 'h23Gq2ngRgIAyKhYUhMlLLXHx6zX4qgT',
    '_cfuvid': 'VRDI51Jr5ukY5cHV6LpDNGasRuA.SOMSwz.rdagSZWk-1710164336150-0.0.1.1-604800000',
    'SURF': '7SLp3RkVlm5hzyNszjIDJ8N7p61HIKwB',
    'SHARED_INDEED_CSRF_TOKEN': 'h23Gq2ngRgIAyKhYUhMlLLXHx6zX4qgT',
    'LV': '"LA=1710166199:LV=1709886385:CV=1710166199:TS=1709129523"',
    'RQ': '"q=data+analyst&l=Lyon+%2869%29&ts=1710166204271:q=data&l=Lyon+%2869%29&radius=10&ts=1709886414177&sc=0kf%3Ajt%28apprenticeship%29%3B:q=consultant+informatique+decisionnelle&l=&ts=1709813609560:q=alternance+data&l=lyon+%2869%29&radius=10&ts=1709129662953&sc=0kf%3Ajt%28apprenticeship%29%3B"',
    'JSESSIONID': 'CCFE8DF2ED601104DBDD37FA2B18CF51',
    'MICRO_CONTENT_CSRF_TOKEN': 'BwtmyDTj2HuJLzcZ7tEhyN0SxJ5pu8Sc',
    'RSJC': 'a88b6d20b1233adc',
    '__cf_bm': 'TvoWmWdXvjF.cdSsav0IR1xGrgfP24Pn9OS4neXgmSY-1710170435-1.0.1.1-ZXI1E8c8CMvDKoRlALTNbJ.pmhG1_IgvK1TDJiHGYrFuFgpm1uO.e4IO9SgA4NZroUmxOfX.5.VVinmomJgPHg',
    'PPEDIT': '1710171041',
    'PPID': 'eyJraWQiOiJkMzZkNmUzNi1lMWJlLTQzNzEtYjY0MS04MGZlZjM3YWQ4N2MiLCJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.....7Cl354h8GO_ZuYTrd2dez1AwdNzUfys_D2CWr2fGFA77iFGEgOrcghgir7n8wJthm7PVUAFVATrrHcWnjrhmvQ',
    'SOCK': '"9mdLEVMyQhUK7QYC4a7VJP4NWJ0="',
    'SHOE': '"uF9ikGNxTxN48dImY9GsWH1gi0Fq0cnYwlGzquPN_kh7W8J2htoGQCSSstMy0DleKY605H4RxXKByvXvBxETe_rhAE6Dbksb927Ir7UutpMxI1GBEGCkrqvMFKwGiXexPk6va7KdGDAVuNLtQJFG7qmT"',
    'MYSTK': '1hon26fm4ike6802',
    'CO': 'FR',
    'LOCALE': 'fr_FR',
    'SKIP_SPLASH': 'true',
    'CO': 'FR',
    'indeed_rcc': '"LOCALE:PREF:cmppmeta:LV:CTK:CO:RQ"',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Mon+Mar+11+2024+16%3A31%3A07+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202210.1.0&isIABGlobal=false&hosts=&consentId=2863f9ff-9e36-4667-81a1-b47792173d1c&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CC0007%3A1&geolocation=%3B&AwaitingReconsent=false',
}

headers = {
    'authority': 'fr.indeed.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'referer': 'https://profile.indeed.com/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
}

params = {
    'from': 'gnav-jobseeker-profile--profile-one-frontend',
}

# Utilisation de la fonction pour extraire les données depuis le site Indeed
df = extract_data_from_indeed(url, headers=headers, cookies=cookies, params=params)

# Afficher le DataFrame
if df is not None:
    display(df)
# Out:
# Erreur lors de la récupération des données. Code de statut: 403

# %% [markdown]
# # Dataframes par localisation

# %%
import pandas as pd
from bs4 import BeautifulSoup

def extract_data_from_html(file_path):
    # Charger le fichier HTML localement
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()

    # Analyser le HTML avec BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extraire les données
    titles = [tag.text for tag in soup.find_all('h2')]
    locations = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='css-1p0sjhy eu4oa1w0')]
    companies = [tag.text if tag.text else 'N/A' for tag in soup.find_all('span', class_='css-92r8pb eu4oa1w0')]
    salaries = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='metadata salary-snippet-container css-5zy3wz eu4oa1w0')]
    job_types = [tag.text if tag.text else 'N/A' for tag in soup.find_all('div', class_='metadata css-5zy3wz eu4oa1w0')]
    links = [tag['href'] for tag in soup.find_all('a', class_='jcs-JobTitle css-jspxzf eu4oa1w0', href=True)]

    # Assurer que toutes les listes ont la même longueur
    min_length = min(len(titles), len(locations), len(companies), len(salaries), len(job_types), len(links))
    titles = titles[:min_length]
    locations = locations[:min_length]
    companies = companies[:min_length]
    salaries = salaries[:min_length]
    job_types = job_types[:min_length]
    links = links[:min_length]

    # Créer un DataFrame pandas avec les données extraites
    df = pd.DataFrame({'Titres': titles, 'Localisation': locations, 'Société': companies, 'Salaire': salaries, 'Type d\'emploi': job_types, 'Lien': links})

    return df

# Utilisation de la fonction pour extraire les données du fichier HTML
df = extract_data_from_html('Emploi_Indeed.html')

# Créer un dictionnaire de dataframes séparés par localisation
dfs_by_location = {location: group for location, group in df.groupby('Localisation')}

# Afficher les dataframes pour chaque localisation
for location, df_location in dfs_by_location.items():
    display(f"Localisation : {location}")
    display(df_location)
# Out:
# "Localisation : 59650 Villeneuve-d'Ascq"
#                         Titres             Localisation  \
# 13  Stage - Data Scientist H/F  59650 Villeneuve-d'Ascq
#
#                         Société             Salaire Type d'emploi  \
# 13  AUCHAN RETAIL INTERNATIONAL  11,65 € de l’heure           CDI
#
#                                                  Lien
# 13  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 'Localisation : 69002 Lyon'
#                                               Titres Localisation Société  \
# 1  Assistant Evènementiel Examens F/H) - alternan...   69002 Lyon   Studi
# 3  Assistant Organisation Examens (F/H) - alterna...   69002 Lyon   Studi
# 5  Chargé des admissions (F/H) - alternance - Lyo...   69002 Lyon   Studi
#
#                              Salaire         Type d'emploi  \
# 1  De 751,30 € à 1 747,20 € par mois         Alternance +1
# 3        De 800 € à 1 200 € par mois         Alternance +1
# ...
